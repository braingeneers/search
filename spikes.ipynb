# %%
import braingeneers.utils.s3wrangler as wr

# get all UUIDs from s3://braingeneers/ephys/
uuids = wr.list_directories('s3://braingeneers/ephys/')
print(uuids)
# Out:
# ['s3://braingeneers/ephys/                                                             2021-06-28-e-test5/', 's3://braingeneers/ephys/                                                             2021-06-28-e-test9/', 's3://braingeneers/ephys/                                                             2021-08-05-e-test4/', 's3://braingeneers/ephys//', 's3://braingeneers/ephys/0000-00-00-e-zip1/', 's3://braingeneers/ephys/0000-00-00-e-zip2/', 's3://braingeneers/ephys/2019-08-09-e-gmpopova/', 's3://braingeneers/ephys/2019-08-09-gmpopova/', 's3://braingeneers/ephys/2019-12-04-e-GS-MG-transplant/', 's3://braingeneers/ephys/2019-12-14-e-GS-MGtransplant/', 's3://braingeneers/ephys/2019-12-14-e-MGK-68-2009/', 's3://braingeneers/ephys/2020-02-10-e-128silicon-c305-jos31c/', 's3://braingeneers/ephys/2020-03-10-e-128silicon-mouse-p35/', 's3://braingeneers/ephys/2020-03-25-e-testit/', 's3://braingeneers/ephys/2020-04-12-e-hengenlab-caf26/', 's3://braingeneers/ephys/2020-06-15-e-MGK-76-2614-PreDrug/', 's3://braingeneers/ephys/2020-06-22-e-MGK-76-2614-PostTTXWash-18hr/', 's3://braingeneers/ephys/2020-06-22-e-MGK-76-2614-PostTTXWash-6d/', 's3://braingeneers/ephys/2020-06-22-e-MGK-76-2614-PostTTXWash/', 's3://braingeneers/ephys/2020-06-22-e-MGK-76-2614-PreTTX/', 's3://braingeneers/ephys/2020-07-06-e-MGK-76-2614-Drug/', 's3://braingeneers/ephys/2020-07-06-e-MGK-76-2614-Drug_0-530/', 's3://braingeneers/ephys/2020-07-06-e-MGK-76-2614-PreDrug/', 's3://braingeneers/ephys/2020-07-06-e-MGK-76-2614-Wash/', 's3://braingeneers/ephys/2020-08-05-dash-example-demo/', 's3://braingeneers/ephys/2020-10-06-e-UCSF-neurons-axionplate/', 's3://braingeneers/ephys/2020-11-05-e-UCSF-axionplate/', 's3://braingeneers/ephys/2020-11-05-e-primary-axion/', 's3://braingeneers/ephys/2020-11-27-e-UCSF-axionplate/', 's3://braingeneers/ephys/2020-11-27-e-primary-axion-Afternoon1/', 's3://braingeneers/ephys/2020-11-27-e-primary-axion-morning/', 's3://braingeneers/ephys/2020-12-01-e-MGK-primary-axion-prestim/', 's3://braingeneers/ephys/2020-12-01-e-MGK-primary-axion-stim-1000mV-10sec/', 's3://braingeneers/ephys/2020-12-01-e-MGK-primary-axion-stim-100mV-60sec/', 's3://braingeneers/ephys/2020-12-01-e-MGK-primary-axion-stim-500mV-20sec/', 's3://braingeneers/ephys/2020-12-01-e-MGK-primary-axion-stim-500mV-2x-10ms-30sec/', 's3://braingeneers/ephys/2020-12-01-e-MGK-primary-axion-stim-500mV-30sec/', 's3://braingeneers/ephys/2020-12-01-e-MGK-primary-axion-stim-500mV-60sec/', 's3://braingeneers/ephys/2020-12-01-e-MGK-primary-axion-stim-500mV_2x-10ms_30sec/', 's3://braingeneers/ephys/2021-01-28-e-2D-MGtransplant-15dpp/', 's3://braingeneers/ephys/2021-01-30-e-2D-MGtransplant-17dpp/', 's3://braingeneers/ephys/2021-02-01-e-2D-MGtransplant-19dpp/', 's3://braingeneers/ephys/2021-02-03-e-2D-MGtransplant-21dpp/', 's3://braingeneers/ephys/2021-02-05-e-2D-MGtransplant-23dpp/', 's3://braingeneers/ephys/2021-02-07-e-2D-MGtransplant-25dpp/', 's3://braingeneers/ephys/2021-02-09-e-2D-MGtransplant-27dpp/', 's3://braingeneers/ephys/2021-02-09-e-2D-MGtransplant-duplicate-13dpp-try2/', 's3://braingeneers/ephys/2021-02-09-e-2D-MGtransplant-duplicate-13dpp/', 's3://braingeneers/ephys/2021-02-11-e-2D-MGtransplant-29dpp/', 's3://braingeneers/ephys/2021-02-11-e-2D-MGtransplant-duplicate-15dpp-try2/', 's3://braingeneers/ephys/2021-02-11-e-2D-MGtransplant-duplicate-15dpp/', 's3://braingeneers/ephys/2021-02-13-e-2D-MGtransplant-31dpp/', 's3://braingeneers/ephys/2021-02-13-e-2D-MGtransplant-duplicate-17dpp-try2/', 's3://braingeneers/ephys/2021-02-13-e-2D-MGtransplant-duplicate-17dpp/', 's3://braingeneers/ephys/2021-02-13-e-2D-MGtransplant-duplicate-19dpp-try2/', 's3://braingeneers/ephys/2021-02-15-e-2D-MGtransplant-33dpp/', 's3://braingeneers/ephys/2021-02-15-e-2D-MGtransplant-duplicate-19dpp-try2/', 's3://braingeneers/ephys/2021-02-15-e-2D-MGtransplant-duplicate-19dpp/', 's3://braingeneers/ephys/2021-02-17-e-2D-MGtransplant-duplicate-21dpp-try2/', 's3://braingeneers/ephys/2021-02-17-e-2D-MGtransplant-duplicate-21 ...

# %%
import braingeneers.data.datasets_electrophysiology as ephys

meta = ephys.load_metadata("2023-05-31-e-speedymouse1")

# %%
data = ephys.load_data(meta, experiment=0, length=1024)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:197: UserWarning: Dataset 2023-05-31-e-speedymouse1 is not in row-major format, the parallel data reader can't be used, read speeds may be slow over a network.
#   warnings.warn(f'Dataset {batch_uuid} is not in row-major format, the parallel data reader '

# %%
meta.keys()
# Out:
# dict_keys(['uuid', 'timestamp', 'maxwell_chip_id', 'notes', 'ephys_experiments'])
